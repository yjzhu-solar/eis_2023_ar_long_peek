# %%
import sys
sys.path.append("/home/yjzhu/scripts/eispac_inspector/")

from eispac_inspector import EISInspector

# %%
# 2023/10/12, bading seeing, west upflow region in leading sunspot 

EISInspector(filename_data="../data/eis_20231013_023510.data.h5",
             filename_fit="../results/eis_20231013_023510.fe_12_195_119.1c-0.fit.h5")
# Out:
# Reading fit result from,
#    ../results/eis_20231013_023510.fe_12_195_119.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231013_023510.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231013_023510.head.h5
# Found window 5
# 2025-11-20 15:08:46 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:08:46 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# 2025-11-20 15:08:47 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# ...

# %%
# 2023/10/14, bad seeing, west upflow region in leading sunspot

EISInspector(filename_data="../data/eis_20231014_005947.data.h5",
             filename_fit="../results/eis_20231014_005947.fe_12_195_119.1c-0.fit.h5")
# Out:
# Reading fit result from,
#    ../results/eis_20231014_005947.fe_12_195_119.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231014_005947.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231014_005947.head.h5
# Found window 5
# /home/yjzhu/scripts/eispac_inspector/eispac_inspector.py:152: RuntimeWarning: invalid value encountered in sqrt
#   true_width_fwhm = np.sqrt( (self.widmap.data * np.sqrt(8*np.log(2)))**2 - self.fit.meta["slit_width"][:,np.newaxis]**2)
# 2025-11-20 15:17:40 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:17:40 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# ...

# %%
# 2023/10/17, good seeing, east upflow region in the trailing sunspot

EISInspector(filename_data="../data/eis_20231016_210248.data.h5",
             filename_fit="../results/eis_20231016_210248.fe_12_195_119.1c-0.fit.h5")
# Out:
# Reading fit result from,
#    ../results/eis_20231016_210248.fe_12_195_119.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231016_210248.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231016_210248.head.h5
# Found window 8
# /home/yjzhu/scripts/eispac_inspector/eispac_inspector.py:152: RuntimeWarning: invalid value encountered in sqrt
#   true_width_fwhm = np.sqrt( (self.widmap.data * np.sqrt(8*np.log(2)))**2 - self.fit.meta["slit_width"][:,np.newaxis]**2)
# 2025-11-20 15:26:01 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:26:01 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# ...

# %%
# 2023/10/17, good seeing, east upflow region in the trailing sunspot

EISInspector(filename_data="../data/eis_20231016_210248.data.h5",
             filename_fit="../results/eis_20231016_210248.fe_08_185_213.1c-0.fit.h5")
# Out:
# Reading fit result from,
#    ../results/eis_20231016_210248.fe_08_185_213.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231016_210248.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231016_210248.head.h5
# Found window 3
# /home/yjzhu/scripts/eispac_inspector/eispac_inspector.py:152: RuntimeWarning: invalid value encountered in sqrt
#   true_width_fwhm = np.sqrt( (self.widmap.data * np.sqrt(8*np.log(2)))**2 - self.fit.meta["slit_width"][:,np.newaxis]**2)
# 2025-12-08 15:00:15 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-12-08 15:00:15 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# ...

# %%
# 2023/10/18, bad seeing, trailing plage region, redshift due to projection effect
# 2023/10/19, good seeing, trailing plage region, redshift due to projection effect

EISInspector(filename_data="../data/eis_20231018_021113.data.h5",
             filename_fit="../results/eis_20231018_021113.fe_12_195_119.1c-0.fit.h5")
# Out:
# Reading fit result from,
#    ../results/eis_20231018_021113.fe_12_195_119.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231018_021113.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231018_021113.head.h5
# Found window 5
# 2025-11-20 15:31:02 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:31:02 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# 2025-11-20 15:31:02 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# ...

# %%
# same region on 2023/10/22, the blueshift in the east region starts to appear

EISInspector(filename_data="../data/eis_20231022_091819.data.h5",
             filename_fit="../results/eis_20231022_091819.fe_12_195_119.1c-0.fit.h5")
# Out:
# /home/yjzhu/scripts/eispac_inspector/eispac_inspector.py:152: RuntimeWarning: invalid value encountered in sqrt
#   true_width_fwhm = np.sqrt( (self.widmap.data * np.sqrt(8*np.log(2)))**2 - self.fit.meta["slit_width"][:,np.newaxis]**2)
# 2025-11-20 15:31:41 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:31:41 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# Reading fit result from,
#    ../results/eis_20231022_091819.fe_12_195_119.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231022_091819.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231022_091819.head.h5
# Found window 3
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# ...

# %%
# 2023/10/20, leading sunpsot, 

EISInspector(filename_data="../data/eis_20231020_045543.data.h5",
             filename_fit="../results/eis_20231020_045543.fe_12_195_119.1c-0.fit.h5")
# Out:
# Reading fit result from,
#    ../results/eis_20231020_045543.fe_12_195_119.1c-0.fit.h5
# Data file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231020_045543.data.h5
# Header file,
#    /home/yjzhu/Solar/eis_2023_ar_long_peek/data/eis_20231020_045543.head.h5
# Found window 5
# /home/yjzhu/scripts/eispac_inspector/eispac_inspector.py:152: RuntimeWarning: invalid value encountered in sqrt
#   true_width_fwhm = np.sqrt( (self.widmap.data * np.sqrt(8*np.log(2)))**2 - self.fit.meta["slit_width"][:,np.newaxis]**2)
# 2025-11-20 15:34:44 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:34:44 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# 2025-11-20 15:34:44 - sunpy - INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere.
# ...
